# %%
from google.colab import files
uploaded = files.upload() #import the JSON

# %%
from google.oauth2 import service_account
from google.cloud import language_v1

client = language_v1.LanguageServiceClient.from_service_account_json("")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0837dcc2591f> in <module>
#       2 from google.cloud import language_v1
#       3
# ----> 4 client = language_v1.LanguageServiceClient.from_service_account_json("")
#
# /usr/local/lib/python3.7/dist-packages/google/cloud/language_v1/gapic/language_service_client.py in from_service_account_file(cls, filename, *args, **kwargs)
#      62             LanguageServiceClient: The constructed client.
#      63         """
# ---> 64         credentials = service_account.Credentials.from_service_account_file(filename)
#      65         kwargs["credentials"] = credentials
#      66         return cls(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/google/oauth2/service_account.py in from_service_account_file(cls, filename, **kwargs)
#     237         """
#     238         info, signer = _service_account_info.from_filename(
# --> 239             filename, require=["client_email", "token_uri"]
#     240         )
#     241         return cls._from_signer_and_info(signer, info, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/google/auth/_service_account_info.py in from_filename(filename, require)
#      70             info and a signer instance.
#      71     """
# ---> 72     with io.open(filename, "r", encoding="utf-8") as json_file:
#      73         data = json.load(json_file)
#      74         return data, from_dict(data, require=require)
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

text="I like apples!"
document = types.Document(content=text,type=enums.Document.Type.PLAIN_TEXT)

sentiment = google_client.analyze_sentiment(document=document)

print_result(sentiment)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-be4f99c9f39f> in <module>
#       1 text = "I love eating apples!"
# ----> 2 document = language_v1.Document(content=text, type_=language_v1.Document.Type.PLAIN_TEXT)
#       3
#       4 sentiment = client.analyze_sentiment(request={'document': document}).document_sentiment
#       5
#
# AttributeError: module 'google.cloud.language_v1' has no attribute 'Document'
