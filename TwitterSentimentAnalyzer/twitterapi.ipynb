# %%
# !pip install git+https://github.com/tweepy/tweepy.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/tweepy/tweepy.git to /tmp/pip-req-build-0x4533u7
#   Running command git clone -q https://github.com/tweepy/tweepy.git /tmp/pip-req-build-0x4533u7
# ...

# %%
import tweepy
import json

# %%
api_key = ""
api_secret = ""
access_key = ""
access_secret = ""

bearer_token = ""

# %%
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
try:
    api.verify_credentials()
    print('Successful Authentication')
except:
    print('Failed authentication')
# Out:
# Successful Authentication

# %%
#testing the home timeline api
timeline = api.home_timeline()
for tweet in timeline:
    print(f"{tweet.user.name} said {tweet.text}")
# Out:
# Kshitij Duraphe said Test tweet
# Bloomberg Markets said The inflation fight is far from over, and global recession alarms are ringing more loudly. See how global goods tra… https://t.co/qWBI8DKbfL
# Bloomberg Markets said “Further interest-rate hikes will be needed to bring the inflation rate back to 2% in the medium term” https://t.co/OI1IQBKBx9
# Bloomberg Markets said China’s electric vehicle startups are defying the venture capital winter https://t.co/TBRFS6Bzie
# Bloomberg Markets said Car flipping has officially gone electric.
#
# One buyer turned his early purchase of a Hummer EV into a quick $35,500… https://t.co/UYJlQ6QzQe
# Bloomberg Markets said JUST IN: “Flying blind is not the way to achieve sustainability,” Bank of England Governor Andrew Bailey said of th… https://t.co/cZ94gdxHNh
# Bloomberg Markets said If Elon Musk really does go through with his acquisition of Twitter, the social media giant will face an annual int… https://t.co/ITfZ6lqQ47
# ...

# %%
#test for posting a tweet
api.update_status("Test tweet 2")

#API - read only happened, needed to update keys!
#status duplicate happened!
# Out:
# Status(_api=<tweepy.api.API object at 0x7efffa340cd0>, _json={'created_at': 'Sat Oct 15 23:41:13 +0000 2022', 'id': 1581430022459752448, 'id_str': '1581430022459752448', 'text': 'Test tweet 2', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/ksd3" rel="nofollow">sentimentec601</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1581271619858743296, 'id_str': '1581271619858743296', 'name': 'Kshitij Duraphe', 'screen_name': 'ec601test', 'location': '', 'description': 'This is a test', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Sat Oct 15 13:11:56 +0000 2022', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'st
# ...

# %%
#testing for different user
user = api.get_user(screen_name="tarik")

print("User details:")
print(user.name)
print(user.description)
print(user.location)

print("Last 20 Followers:")
for follower in user.followers():
    print(follower.name)

#had api error - user not found!
# Out:
# User details:
# tarik
# content creator @Sentinels | https://t.co/TVMyANTInc | https://t.co/YrUAK9yj0p - biz: tarik@loaded.gg
# Brooklyn, NY
# Last 20 Followers:
# miftz
# SEN Sacy
# IruCa
# Minmax
# Who is Morislk
# efr exe
# sahar
# Jacob Powell
# wtfcadu
# Vithuran
# yas
# htr.-
# Vic
# Pfftttt
# JenitalJenga
# Luis
# Hoang tran
# Komodo
# 🐝
# Thomas Ng

# %%
#testing to follow users
api.create_friendship(screen_name="realpython")
# Out:
# User(_api=<tweepy.api.API object at 0x7efffa340cd0>, _json={'id': 745911914, 'id_str': '745911914', 'name': 'Real Python', 'screen_name': 'realpython', 'location': '', 'description': 'Online #Python Training & Expert Community: Tutorials, Video Courses, Books, Quizzes...and More! Join 3,000,000 Monthly Readers at https://t.co/TyrG6Kkaq6', 'url': 'https://t.co/TyrG6KBLOG', 'entities': {'url': {'urls': [{'url': 'https://t.co/TyrG6KBLOG', 'expanded_url': 'http://realpython.com', 'display_url': 'realpython.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/TyrG6Kkaq6', 'expanded_url': 'http://realpython.com', 'display_url': 'realpython.com', 'indices': [131, 154]}]}}, 'protected': False, 'followers_count': 165888, 'friends_count': 164, 'listed_count': 3216, 'created_at': 'Wed Aug 08 20:44:42 +0000 2012', 'favourites_count': 58206, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 60077, 'lang': None, 'status': {'cre
# ...

# %%
#test to unfollow users:
api.destroy_friendship(screen_name="realpython")
# Out:
# User(_api=<tweepy.api.API object at 0x7efffa340cd0>, _json={'id': 745911914, 'id_str': '745911914', 'name': 'Real Python', 'screen_name': 'realpython', 'location': '', 'description': 'Online #Python Training & Expert Community: Tutorials, Video Courses, Books, Quizzes...and More! Join 3,000,000 Monthly Readers at https://t.co/TyrG6Kkaq6', 'url': 'https://t.co/TyrG6KBLOG', 'entities': {'url': {'urls': [{'url': 'https://t.co/TyrG6KBLOG', 'expanded_url': 'http://realpython.com', 'display_url': 'realpython.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/TyrG6Kkaq6', 'expanded_url': 'http://realpython.com', 'display_url': 'realpython.com', 'indices': [131, 154]}]}}, 'protected': False, 'followers_count': 165887, 'friends_count': 164, 'listed_count': 3216, 'created_at': 'Wed Aug 08 20:44:42 +0000 2012', 'favourites_count': 58206, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 60077, 'lang': None, 'status': {'cre
# ...

# %%
#test to update profile
api.update_profile(description="This is a test 2")
# Out:
# User(_api=<tweepy.api.API object at 0x7efffa340cd0>, _json={'id': 1581271619858743296, 'id_str': '1581271619858743296', 'name': 'Kshitij Duraphe', 'screen_name': 'ec601test', 'location': '', 'profile_location': None, 'description': 'This is a test 2', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Sat Oct 15 13:11:56 +0000 2022', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2, 'lang': None, 'status': {'created_at': 'Sat Oct 15 23:41:13 +0000 2022', 'id': 1581430022459752448, 'id_str': '1581430022459752448', 'text': 'Test tweet 2', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/ksd3" rel="nofollow">sentimentec601</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_re
# ...

# %%
#test to like tweet
tweets = api.home_timeline(count=2)
tweet = tweets[0]
print(f"Liking tweet {tweet.id} of {tweet.author.name}")
api.create_favorite(tweet.id)
# Out:
# Liking tweet 1581430022459752448 of Kshitij Duraphe
# ...

# %%
#test to block a user
api.create_block(screen_name="nasa")
# Out:
# User(_api=<tweepy.api.API object at 0x7efffa340cd0>, _json={'id': 11348282, 'id_str': '11348282', 'name': 'NASA', 'screen_name': 'NASA', 'location': 'Pale Blue Dot', 'description': "There's space for everybody. ✨", 'url': 'https://t.co/9NkQJKAnuU', 'entities': {'url': {'urls': [{'url': 'https://t.co/9NkQJKAnuU', 'expanded_url': 'http://www.nasa.gov/', 'display_url': 'nasa.gov', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 64318244, 'friends_count': 185, 'listed_count': 99854, 'created_at': 'Wed Dec 19 20:20:32 +0000 2007', 'favourites_count': 14409, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 68838, 'lang': None, 'status': {'created_at': 'Sat Oct 15 21:02:04 +0000 2022', 'id': 1581389969154658304, 'id_str': '1581389969154658304', 'text': 'Our workforce is our strength. Check out our Twitter Moment for a recap of #HispanicHeritageMonth and… https://t.co/SIwFmCQhXA', 'truncated': True, '
# ...

# %%
#test to unblock
api.destroy_block(screen_name="nasa")
# Out:
# User(_api=<tweepy.api.API object at 0x7efffa340cd0>, _json={'id': 11348282, 'id_str': '11348282', 'name': 'NASA', 'screen_name': 'NASA', 'location': 'Pale Blue Dot', 'description': "There's space for everybody. ✨", 'url': 'https://t.co/9NkQJKAnuU', 'entities': {'url': {'urls': [{'url': 'https://t.co/9NkQJKAnuU', 'expanded_url': 'http://www.nasa.gov/', 'display_url': 'nasa.gov', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 64318249, 'friends_count': 185, 'listed_count': 99854, 'created_at': 'Wed Dec 19 20:20:32 +0000 2007', 'favourites_count': 14409, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 68838, 'lang': None, 'status': {'created_at': 'Sat Oct 15 21:02:04 +0000 2022', 'id': 1581389969154658304, 'id_str': '1581389969154658304', 'text': 'Our workforce is our strength. Check out our Twitter Moment for a recap of #HispanicHeritageMonth and… https://t.co/SIwFmCQhXA', 'truncated': True, '
# ...

# %%
#this is the most important section! this shows how tweets are gathered
#here we're searching tweets containing the string "Python" and in English, and 10 of them
for tweet in api.search_tweets(q="ukraine", lang="en"):#, rpp=15):
    print(f"{tweet.user.name}:{tweet.text}")

#query parameters are missing error happened
#private vs public tweets - can't work because that's not what twitter supports
# Out:
# Mulu abraha🥰🎯:RT @titi_tigraweyt: Some analysts believe Tigray war
# is worse than the Ukraine-Russia war and it has been overlooked by the world. The Erit…
# Omo Oriolowo 🇳🇬 🇿🇲 🇵🇱 🇬🇧:RT @VeraVanHorne: Do you see that history repeats itself in Ukraine?.. https://t.co/thB1jXm7OA
# Daniel Asher 🌻🇺🇦🤝🇺🇸🌊:@GentlemanLoser @socialiststeve6 Send F-16s, A-10s, Patriot, NASAMS, Abrams, knives, sharp sticks!
#
# Because if the… https://t.co/AI3Ao2jU4n
# Nadew:RT @tewerwari_1: US corporate affiliated elites nervously urging Biden Admin to enter z war in #Ethiopia siding with #TPLF. After turning #…
# Abba Sanni:RT @elonmusk: The hell with it … even though Starlink is still losing money &amp; other companies are getting billions of taxpayer $, we’ll jus…
# SuperSticksPro:@DavidSacks @elonmusk Ukraine gov are just puppets of the USA government, and they are THE terrorists: https://t.co/PqD425egTo
# ...

# %%
#checking trends test

api.closest_trends(10,20)
# Out:
# [{'name': 'Nigeria',
#   'placeType': {'code': 12, 'name': 'Country'},
#   'url': 'http://where.yahooapis.com/v1/place/23424908',
#   'parentid': 1,
#   'country': 'Nigeria',
#   'woeid': 23424908,
#   'countryCode': 'NG'}]

# %%
import pandas as pd

# %%
#setting up to stream only for a certain amount of time
from datetime import datetime, timedelta

# %%
#streaming test
#export to pandas dataframe

stream=tweepy.Stream(api_key,api_secret,access_key,access_secret)
streaming_client = tweepy.StreamingClient(bearer_token)
streaming_client.add_rules(tweepy.StreamRule("ukraine"))
#streaming_client.filter()

